bad_beta0_MAPE = list(map(float, '0.1770983 0.1563418 0.1424746 0.08320439 0.1431089 0.09041382 0.09337137 0.07887271 0.08528267 0.09388893 0.08011376 0.0640661 0.06802876 0.05864015 0.06035931 0.06084247 0.06380902 0.06001824 0.06126558 0.07095702 0.06434583 0.04478044 0.05131588 0.04763886 0.05846766 0.06348577'.split(' '),))
bad_beta1_MAPE = list(map(float, '0.03194677 0.0291138 0.02649068 0.01860551 0.01959614 0.01684975 0.01828929 0.01597858 0.01703651 0.01724928 0.01693763 0.01243261 0.01459226 0.0111811 0.01147139 0.01254952 0.0147914 0.01273838 0.01289727 0.01232385 0.01251284 0.01000976 0.01077816 0.00971679 0.01052266 0.01154311'.split(' '),))
bad_beta2_MAPE = list(map(float, '0.003317019 0.003462032 0.002620649 0.001828671 0.002208147 0.001880118 0.001556231 0.001943459 0.001900827 0.001735677 0.00156784 0.001554748 0.001652855 0.00150181 0.001482877 0.001576865 0.00143561 0.00132555 0.001241253 0.001258074 0.001481438 0.001107605 0.001314575 0.001043411 0.001080237 0.001177575'.split(' '),))

# %%
fig, axs = plt.subplots(3, 2, figsize=(20, 10))
axs[0, 0].plot(np.arange(50, 301, 10), bad_beta0_MAPE, label='Bayes')
axs[0, 0].plot(np.arange(50, 301, 10), ml_beta0_MAPE, label='ML')
axs[0, 0].set_title('MAPE')
axs[0, 0].set(ylabel='beta_0')
axs[0, 1].plot(np.arange(50, 301, 10), bad_beta0_RMSE, label='Bayes')
axs[0, 1].plot(np.arange(50, 301, 10), ml_beta0_RMSE, label='ML')
axs[0, 1].set_title('RMSE')
axs[0, 1].legend(loc="upper right")

axs[1, 0].plot(np.arange(50, 301, 10), bad_beta1_MAPE, label='Bayes')
axs[1, 0].plot(np.arange(50, 301, 10), ml_beta1_MAPE, label='ML')

axs[1, 0].set(ylabel='beta_1')
axs[1, 1].plot(np.arange(50, 301, 10), bad_beta1_RMSE, label='Bayes')
axs[1, 1].plot(np.arange(50, 301, 10), ml_beta1_RMSE, label='ML')


axs[2, 0].plot(np.arange(50, 301, 10), bad_beta2_MAPE, label='Bayes')
axs[2, 0].plot(np.arange(50, 301, 10), ml_beta2_MAPE, label='ML')

axs[2, 0].set(ylabel='beta_2')
axs[2, 1].plot(np.arange(50, 301, 10), bad_beta2_RMSE, label='Bayes')
axs[2, 1].plot(np.arange(50, 301, 10), ml_beta2_RMSE, label='ML')
axs[2, 0].set(xlabel='sample size')
axs[2, 1].set(xlabel='sample size')
plt.savefig('bad_prior.pdf');

# %%
semigood_beta0_RMSE = list(map(float, '0.3556992 0.3495408 0.332316 0.24508 0.2648785 0.1987743 0.2010805 0.2122661 0.219934 0.2234425 0.1908771 0.1710628 0.1939903 0.156709 0.1572833 0.1963808 0.1827311 0.1564207 0.1603249 0.1638177 0.1677316 0.1381992 0.1384914 0.1306722 0.1323391 0.1477111'.split(' '),))
semigood_beta1_RMSE = list(map(float, '0.1790481 0.1700622 0.1691387 0.1269131 0.1196429 0.1013716 0.1041292 0.1045225 0.1076917 0.1004105 0.1028079 0.0824268 0.09174411 0.0742912 0.07488647 0.08631745 0.09019843 0.07795597 0.08141434 0.08310358 0.07845785 0.06825906 0.07405067 0.06406639 0.06281492 0.0748861'.split(' '),))
semigood_beta2_RMSE = list(map(float, '0.04107013 0.04186084 0.03134996 0.02324908 0.02892441 0.02208673 0.02081786 0.02687137 0.02487899 0.0215292 0.01817652 0.01799329 0.02032413 0.01750642 0.01773638 0.02090719 0.01825372 0.01653652 0.01641714 0.01632549 0.01884662 0.01438365 0.01692679 0.01453529 0.0129585 0.01461751'.split(' '),))
semigood_beta0_MAPE = list(map(float, '0.1673687 0.154342 0.1470094 0.08886473 0.1565987 0.08579867 0.08565014 0.08493991 0.08545623 0.1021747 0.07312885 0.05900707 0.06800939 0.05815776 0.05974583 0.06869203 0.06624314 0.05825159 0.06011463 0.07143368 0.06389936 0.04783611 0.05238246 0.05128766 0.05457626 0.06584199'.split(' '),))
semigood_beta1_MAPE = list(map(float, '0.02963459 0.02819526 0.02757599 0.01996973 0.02057179 0.01617629 0.01683848 0.01643427 0.01681184 0.01678695 0.01585398 0.01267672 0.01421227 0.01160219 0.01182467 0.01369678 0.01448555 0.01201628 0.01300565 0.01316882 0.01237157 0.01052863 0.01194126 0.0100462 0.009934559 0.01241169'.split(' '),))
semigood_beta2_MAPE = list(map(float, '0.00325002 0.003460949 0.002491184 0.001864719 0.002305535 0.001769564 0.001640794 0.002145883 0.001993539 0.00175479 0.001461381 0.001465632 0.001622418 0.001394761 0.001434191 0.001695546 0.001436086 0.001340906 0.001301654 0.001285857 0.001493778 0.001125416 0.001363961 0.001165948 0.001034958 0.001160581'.split(' '),))

# %%
fig, axs = plt.subplots(3, 2, figsize=(20, 10))
axs[0, 0].plot(np.arange(50, 301, 10), semigood_beta0_MAPE, label='Bayes')
axs[0, 0].plot(np.arange(50, 301, 10), ml_beta0_MAPE, label='ML')
axs[0, 0].set_title('MAPE')
axs[0, 0].set(ylabel='beta_0')
axs[0, 1].plot(np.arange(50, 301, 10), semigood_beta0_RMSE, label='Bayes')
axs[0, 1].plot(np.arange(50, 301, 10), ml_beta0_RMSE, label='ML')
axs[0, 1].set_title('RMSE')
axs[0, 1].legend(loc="upper right")

axs[1, 0].plot(np.arange(50, 301, 10), semigood_beta1_MAPE, label='Bayes')
axs[1, 0].plot(np.arange(50, 301, 10), ml_beta1_MAPE, label='ML')

axs[1, 0].set(ylabel='beta_1')
axs[1, 1].plot(np.arange(50, 301, 10), semigood_beta1_RMSE, label='Bayes')
axs[1, 1].plot(np.arange(50, 301, 10), ml_beta1_RMSE, label='ML')


axs[2, 0].plot(np.arange(50, 301, 10), semigood_beta2_MAPE, label='Bayes')
axs[2, 0].plot(np.arange(50, 301, 10), ml_beta2_MAPE, label='ML')

axs[2, 0].set(ylabel='beta_2')
axs[2, 1].plot(np.arange(50, 301, 10), semigood_beta2_RMSE, label='Bayes')
axs[2, 1].plot(np.arange(50, 301, 10), ml_beta2_RMSE, label='ML')
axs[2, 0].set(xlabel='sample size')
axs[2, 1].set(xlabel='sample size')
plt.savefig('semigood_prior.pdf');

# %%
good_beta0_RMSE = list(map(float, '0.3254357 0.3391762 0.2936775 0.2477973 0.2385478 0.2049758 0.2082888 0.2016364 0.2115574 0.1967622 0.1802384 0.1675154 0.2065417 0.1541901 0.1726409 0.1752328 0.1730905 0.1657556 0.1598962 0.1611263 0.1443748 0.1335061 0.1330932 0.1170553 0.1436285 0.144877'.split(' '),))
good_beta1_RMSE = list(map(float, '0.1692985 0.1619884 0.1467754 0.1250092 0.1210225 0.1036866 0.1069869 0.1040684 0.1110013 0.09252222 0.09533849 0.08470761 0.09377623 0.07412836 0.07579312 0.07952401 0.09166828 0.08527626 0.08065181 0.0805108 0.07188513 0.06475236 0.06974314 0.05815588 0.06724127 0.07380082'.split(' '),))
good_beta2_RMSE = list(map(float, '0.04068431 0.04393667 0.03118725 0.02288609 0.0269607 0.02283119 0.0208786 0.02416294 0.02310662 0.02102934 0.01948089 0.01719321 0.02242159 0.01820741 0.01919979 0.01997379 0.01725053 0.01708191 0.01565732 0.0165964 0.01687855 0.01516912 0.01584942 0.01423394 0.01286613 0.01444027'.split(' '),))
good_beta0_MAPE = list(map(float, '0.1511184 0.1428633 0.1310099 0.09074997 0.1366269 0.0865949 0.08746007 0.07874755 0.08129716 0.08997481 0.07060862 0.05670897 0.07154319 0.05807294 0.06384156 0.06092442 0.06155276 0.06027569 0.06050499 0.0685446 0.05571599 0.04638939 0.04989412 0.04655556 0.05982015 0.06416502'.split(' '),))
good_beta1_MAPE = list(map(float, '0.02836696 0.02663238 0.02378357 0.0196988 0.02045447 0.0165719 0.01743311 0.01637352 0.01740284 0.01549074 0.01479267 0.01301944 0.01450231 0.01187803 0.01193841 0.01244302 0.01446572 0.01311021 0.01271229 0.01256479 0.01132543 0.009985025 0.01111316 0.00916872 0.01087146 0.01203645'.split(' '),))
good_beta2_MAPE = list(map(float, '0.003255013 0.003448527 0.002524569 0.001846875 0.002145568 0.001806796 0.00164187 0.001925217 0.001836193 0.001701394 0.00155591 0.001368579 0.001781119 0.001456188 0.001535674 0.001577566 0.001366568 0.001362392 0.001242292 0.001318365 0.001354638 0.001217187 0.001255585 0.001143237 0.001022696 0.00117072'.split(' '),))

# %%
fig, axs = plt.subplots(3, 2, figsize=(20, 10))
axs[0, 0].plot(np.arange(50, 301, 10), good_beta0_MAPE, label='Bayes')
axs[0, 0].plot(np.arange(50, 301, 10), ml_beta0_MAPE, label='ML')
axs[0, 0].set_title('MAPE')
axs[0, 0].set(ylabel='beta_0')
axs[0, 1].plot(np.arange(50, 301, 10), good_beta0_RMSE, label='Bayes')
axs[0, 1].plot(np.arange(50, 301, 10), ml_beta0_RMSE, label='ML')
axs[0, 1].set_title('RMSE')
axs[0, 1].legend(loc="upper right")

axs[1, 0].plot(np.arange(50, 301, 10), good_beta1_MAPE, label='Bayes')
axs[1, 0].plot(np.arange(50, 301, 10), ml_beta1_MAPE, label='ML')

axs[1, 0].set(ylabel='beta_1')
axs[1, 1].plot(np.arange(50, 301, 10), good_beta1_RMSE, label='Bayes')
axs[1, 1].plot(np.arange(50, 301, 10), ml_beta1_RMSE, label='ML')


axs[2, 0].plot(np.arange(50, 301, 10), good_beta2_MAPE, label='Bayes')
axs[2, 0].plot(np.arange(50, 301, 10), ml_beta2_MAPE, label='ML')

axs[2, 0].set(ylabel='beta_2')
axs[2, 1].plot(np.arange(50, 301, 10), good_beta2_RMSE, label='Bayes')
axs[2, 1].plot(np.arange(50, 301, 10), ml_beta2_RMSE, label='ML')
axs[2, 0].set(xlabel='sample size')
axs[2, 1].set(xlabel='sample size')
plt.savefig('semigood_prior.pdf');
