bad_beta0_MAPE = list(map(float, '0.1293295 0.04405248 0.2358493 0.02145212 0.06103024 0.0302634 0.02188528 0.09275068 0.1858669 0.02089539 0.05272758 0.02886054 0.1020172 0.1227577 0.04968207 0.01959204 0.09364661 0.01313761 0.05858364 0.009307423 0.03269666 0.04969641 0.003201699 0.005870726 0.01090212 0.05531359'.split(' '),))
bad_beta1_MAPE = list(map(float, '0.004977213 0.001577823 0.03878609 0.01435215 0.005637549 0.02552778 0.005094264 0.03286713 0.02095928 0.006245645 0.004423647 0.004393675 0.01666477 0.03156217 0.005822965 0.007729452 0.03472225 0.00246319 0.03211046 0.01320601 0.008952527 0.0008854151 0.0006593185 0.0008612274 0.01962048 0.001679137'.split(' '),))
bad_beta2_MAPE = list(map(float, '0.003639631 0.00103652 0.001492248 0.001441516 0.0009691464 0.001681848 0.002577965 0.002109297 0.0009357477 0.0005503133 0.0005294662 0.0002383152 0.001127384 0.0009518946 0.000288932 0.002569279 0.001777317 0.0006246969 6.524792e-05 0.0008654211 0.001539522 0.002557887 0.001178596 0.0006621754 0.0001799808 0.002125247'.split(' '),))

# %%
fig, axs = plt.subplots(3, 2, figsize=(20, 10))
axs[0, 0].plot(np.arange(50, 301, 10), bad_beta0_MAPE, label='Bayes', linestyle='--')
axs[0, 0].plot(np.arange(50, 301, 10), ml_beta0_MAPE, label='ML', alpha=0.5)
axs[0, 0].set_title('MAPE')
axs[0, 0].set(ylabel='beta_0')
axs[0, 1].plot(np.arange(50, 301, 10), bad_beta0_RMSE, label='Bayes', linestyle='--')
axs[0, 1].plot(np.arange(50, 301, 10), ml_beta0_RMSE, label='ML', alpha=0.5)
axs[0, 1].set_title('RMSE')
axs[0, 1].legend(loc="upper right")

axs[1, 0].plot(np.arange(50, 301, 10), bad_beta1_MAPE, label='Bayes', linestyle='--')
axs[1, 0].plot(np.arange(50, 301, 10), ml_beta1_MAPE, label='ML', alpha=0.5)

axs[1, 0].set(ylabel='beta_1')
axs[1, 1].plot(np.arange(50, 301, 10), bad_beta1_RMSE, label='Bayes', linestyle='--')
axs[1, 1].plot(np.arange(50, 301, 10), ml_beta1_RMSE, label='ML', alpha=0.5)


axs[2, 0].plot(np.arange(50, 301, 10), bad_beta2_MAPE, label='Bayes', linestyle='--')
axs[2, 0].plot(np.arange(50, 301, 10), ml_beta2_MAPE, label='ML', alpha=0.5)

axs[2, 0].set(ylabel='beta_2')
axs[2, 1].plot(np.arange(50, 301, 10), bad_beta2_RMSE, label='Bayes', linestyle='--')
axs[2, 1].plot(np.arange(50, 301, 10), ml_beta2_RMSE, label='ML', alpha=0.5)
axs[2, 0].set(xlabel='sample size')
axs[2, 1].set(xlabel='sample size')
plt.savefig('bad_prior.pdf');

# %%
semigood_beta0_RMSE = list(map(float, '0.2547511 0.09108578 0.4709051 0.04492004 0.1198959 0.05951537 0.04118046 0.1878739 0.3700349 0.04162228 0.1068848 0.05775348 0.2041501 0.2465318 0.0994858 0.03940211 0.1878162 0.02775391 0.1150841 0.01787134 0.06584646 0.09773129 0.007005583 0.01168283 0.02012177 0.1117775'.split(' '),))
semigood_beta1_RMSE = list(map(float, '0.02321325 0.007728613 0.1941246 0.07349595 0.02724247 0.1267272 0.02665791 0.1659085 0.1038968 0.03075059 0.02331307 0.02225706 0.08319179 0.1586909 0.02956777 0.03958431 0.1740883 0.01299314 0.1594103 0.06609539 0.04406065 0.004992279 0.003446937 0.004096948 0.09887123 0.008153106'.split(' '),))
semigood_beta2_RMSE = list(map(float, '0.03615167 0.01042242 0.01480468 0.01463711 0.009821878 0.01676042 0.02557184 0.02113014 0.009375881 0.005371285 0.005275804 0.002486081 0.01130985 0.009597824 0.002961196 0.0258468 0.01786148 0.006248013 0.0005913205 0.008788272 0.01520963 0.02554199 0.01187958 0.006559612 0.001753521 0.02137393'.split(' '),))
semigood_beta0_MAPE = list(map(float, '0.1273756 0.04554289 0.2354526 0.02246002 0.05994796 0.02975768 0.02059023 0.09393693 0.1850174 0.02081114 0.05344239 0.02887674 0.102075 0.1232659 0.0497429 0.01970105 0.09390811 0.01387695 0.05754205 0.008935672 0.03292323 0.04886565 0.003502792 0.005841413 0.01006089 0.05588877'.split(' '),))
semigood_beta1_MAPE = list(map(float, '0.00464265 0.001545723 0.03882492 0.01469919 0.005448493 0.02534545 0.005331582 0.03318169 0.02077937 0.006150118 0.004662613 0.004451413 0.01663836 0.03173818 0.005913555 0.007916863 0.03481765 0.002598627 0.03188205 0.01321908 0.00881213 0.0009984559 0.0006893875 0.0008193896 0.01977425 0.001630621'.split(' '),))
semigood_beta2_MAPE = list(map(float, '0.003615167 0.001042242 0.001480468 0.001463711 0.0009821878 0.001676042 0.002557184 0.002113014 0.0009375881 0.0005371285 0.0005275804 0.0002486081 0.001130985 0.0009597824 0.0002961196 0.00258468 0.001786148 0.0006248013 5.913205e-05 0.0008788272 0.001520963 0.002554199 0.001187958 0.0006559612 0.0001753521 0.002137393'.split(' '),))

# %%
fig, axs = plt.subplots(3, 2, figsize=(20, 10))
axs[0, 0].plot(np.arange(50, 301, 10), semigood_beta0_MAPE, label='Bayes', linestyle='--')
axs[0, 0].plot(np.arange(50, 301, 10), ml_beta0_MAPE, label='ML', alpha=0.5)
axs[0, 0].set_title('MAPE')
axs[0, 0].set(ylabel='beta_0')
axs[0, 1].plot(np.arange(50, 301, 10), semigood_beta0_RMSE, label='Bayes', linestyle='--')
axs[0, 1].plot(np.arange(50, 301, 10), ml_beta0_RMSE, label='ML', alpha=0.5)
axs[0, 1].set_title('RMSE')
axs[0, 1].legend(loc="upper right")

axs[1, 0].plot(np.arange(50, 301, 10), semigood_beta1_MAPE, label='Bayes', linestyle='--')
axs[1, 0].plot(np.arange(50, 301, 10), ml_beta1_MAPE, label='ML', alpha=0.5)

axs[1, 0].set(ylabel='beta_1')
axs[1, 1].plot(np.arange(50, 301, 10), semigood_beta1_RMSE, label='Bayes', linestyle='--')
axs[1, 1].plot(np.arange(50, 301, 10), ml_beta1_RMSE, label='ML', alpha=0.5)


axs[2, 0].plot(np.arange(50, 301, 10), semigood_beta2_MAPE, label='Bayes', linestyle='--')
axs[2, 0].plot(np.arange(50, 301, 10), ml_beta2_MAPE, label='ML', alpha=0.5)

axs[2, 0].set(ylabel='beta_2')
axs[2, 1].plot(np.arange(50, 301, 10), semigood_beta2_RMSE, label='Bayes', linestyle='--')
axs[2, 1].plot(np.arange(50, 301, 10), ml_beta2_RMSE, label='ML', alpha=0.5)
axs[2, 0].set(xlabel='sample size')
axs[2, 1].set(xlabel='sample size')
plt.savefig('semigood_prior.pdf');

# %%
good_beta0_RMSE = list(map(float, '0.2229915 0.08301651 0.4349327 0.04233649 0.1143258 0.05300569 0.03954243 0.1756366 0.3443684 0.04158352 0.1042328 0.0563054 0.1964263 0.2370838 0.09629502 0.03835754 0.1820722 0.02472591 0.110265 0.0181732 0.06385936 0.09529707 0.006367515 0.0100263 0.02162563 0.1091303'.split(' '),))
good_beta1_RMSE = list(map(float, '0.01194257 0.008109602 0.18069 0.0720117 0.02559887 0.1234548 0.0268441 0.1612597 0.09410391 0.03093289 0.02180342 0.02258869 0.08006119 0.1538465 0.02855011 0.03904881 0.1719397 0.01216804 0.1572227 0.06549793 0.04492314 0.006183849 0.003029605 0.004759226 0.09820689 0.009397284'.split(' '),))
good_beta2_RMSE = list(map(float, '0.03468898 0.009813054 0.01293573 0.01465924 0.01016607 0.01673824 0.02542534 0.02177717 0.0080618 0.005357251 0.005204415 0.002360116 0.01089453 0.009774085 0.003152052 0.02593017 0.01811887 0.006069325 0.0005928252 0.008654424 0.01520071 0.02546711 0.01183825 0.006510371 0.001770669 0.02130126'.split(' '),))
good_beta0_MAPE = list(map(float, '0.1114957 0.04150826 0.2174663 0.02116825 0.05716289 0.02650285 0.01977121 0.08781831 0.1721842 0.02079176 0.05211641 0.0281527 0.09821317 0.1185419 0.04814751 0.01917877 0.09103611 0.01236296 0.05513251 0.009086602 0.03192968 0.04764853 0.003183758 0.005013152 0.01081282 0.05456513'.split(' '),))
good_beta1_MAPE = list(map(float, '0.002388515 0.00162192 0.036138 0.01440234 0.005119774 0.02469095 0.00536882 0.03225194 0.01882078 0.006186579 0.004360684 0.004517738 0.01601224 0.03076931 0.005710023 0.007809762 0.03438793 0.002433607 0.03144454 0.01309959 0.008984628 0.00123677 0.0006059211 0.0009518452 0.01964138 0.001879457'.split(' '),))
good_beta2_MAPE = list(map(float, '0.003468898 0.0009813054 0.001293573 0.001465924 0.001016607 0.001673824 0.002542534 0.002177717 0.00080618 0.0005357251 0.0005204415 0.0002360116 0.001089453 0.0009774085 0.0003152052 0.002593017 0.001811887 0.0006069325 5.928252e-05 0.0008654424 0.001520071 0.002546711 0.001183825 0.0006510371 0.0001770669 0.002130126'.split(' '),))

# %%
fig, axs = plt.subplots(3, 2, figsize=(20, 10))
axs[0, 0].plot(np.arange(50, 301, 10), good_beta0_MAPE, label='Bayes', linestyle='--')
axs[0, 0].plot(np.arange(50, 301, 10), ml_beta0_MAPE, label='ML')
axs[0, 0].set_title('MAPE')
axs[0, 0].set(ylabel='beta_0')
axs[0, 1].plot(np.arange(50, 301, 10), good_beta0_RMSE, label='Bayes', linestyle='--')
axs[0, 1].plot(np.arange(50, 301, 10), ml_beta0_RMSE, label='ML')
axs[0, 1].set_title('RMSE')
axs[0, 1].legend(loc="upper right")

axs[1, 0].plot(np.arange(50, 301, 10), good_beta1_MAPE, label='Bayes', linestyle='--')
axs[1, 0].plot(np.arange(50, 301, 10), ml_beta1_MAPE, label='ML')

axs[1, 0].set(ylabel='beta_1')
axs[1, 1].plot(np.arange(50, 301, 10), good_beta1_RMSE, label='Bayes', linestyle='--')
axs[1, 1].plot(np.arange(50, 301, 10), ml_beta1_RMSE, label='ML')


axs[2, 0].plot(np.arange(50, 301, 10), good_beta2_MAPE, label='Bayes', linestyle='--')
axs[2, 0].plot(np.arange(50, 301, 10), ml_beta2_MAPE, label='ML')

axs[2, 0].set(ylabel='beta_2')
axs[2, 1].plot(np.arange(50, 301, 10), good_beta2_RMSE, label='Bayes', linestyle='--')
axs[2, 1].plot(np.arange(50, 301, 10), ml_beta2_RMSE, label='ML')
axs[2, 0].set(xlabel='sample size')
axs[2, 1].set(xlabel='sample size')
plt.savefig('semigood_prior.pdf');
